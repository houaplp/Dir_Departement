# %% [markdown]
# # Classes

# %% [markdown]
# ## 1-Enseignants

# %%
import os
import math
import glob
import re
import operator
import time
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class Enseignant:
    def __init__(self, nom, prenom, statut):
        self.nom = nom
        self.prenom=prenom
        self.telephone="nil"
        self.mail_ujm="nil"
        self.mail_perso="nil"
        self.adresse="nil"
        self.statut=statut
        self.Lcours=[]
        self.charge=[]
        self.service=0

class Niveau: 
    def __init__(self, niveau):
        self.niveau = niveau
        
class Enseignement:
    def __init__(self, niveau, semestre, code, titre, groupes):
        self.niveau = niveau
        self.semestre = semestre
        self.code = code
        self.titre = titre
        self.htd = 0
        self.hcm = 0
        self.groupes = groupes
        self.Lcours = []
                
class Charge_admin:
    def __init__(self, titre, htd):
        self.titre = titre
        self.htd = htd
        self.rqs = "nil"
        
class Cours:
    def __init__(self, enseignant, enseignement):
        self.enseignant = enseignant
        self.enseignement = enseignement
        self.duree = 0
        self.nseances = 0
        self.groupes = 0
        self.dates = []
        self.hdebut = 0
        self.jour = "nil"
        self.type = "TD"
        self.salle = "nil"
        self.groupe = "nil"
        self.rqs = "nil"
        self.plan = "nil"
        
class Salle:
    def __init__ (self, site, code, music):
        self.site = site
        self.code = code
        self.music = music
    def __lt__ (self, other):
        return self.site < other.site
    
SallesMusic = ["HR8","J02", "J11"]   

#print ("HR8" in SallesMusic)

# %%
os.chdir("/Users/laurentpottier/Documents/LP/Recherches/Dir_Departement/Python_Planning/files/")

# %%
X = pd.read_excel("Services_enseignants2022-23i.xlsx",sheet_name=0,header=0,index_col=0)

# %%
#print(X.shape) # (18, 6)
print (X.index[3])
#print (X.columns[2])
#print (X.nom[2])
#print (X.niveau[2])
#print (X.site[2])
#print (X.salle[2])
#print (X.duree[2])
#print (type(X.rqs[2]))
#heure1 = X.début[2]
#print (heure1)
#print (heure1.hour)
#print (heure1.minute)
#print (type (heure1))
#print (type (5))
#print (type (08:00:00))
#HOUR = timedelta(hours=1)
#print (dir(HOUR))
#print (type (HOUR))
#print (dir(heure1))
#print (heure1.minute)
#print ("heure1, datetime.time :" , isinstance (heure1, datetime.time))
# Out:
# 4

# %%
#print (Enseignants)
#print (Enseignants[0].nom)
#print (len(Enseignants))

def noms_enseignants(ListeEnseignants):
    res = []
    for i in range (len(ListeEnseignants)):
        res.append (ListeEnseignants[i].nom)
    return res

def prenoms_enseignants(ListeEnseignants):
    res = []
    for i in range (len(ListeEnseignants)):
        res.append (ListeEnseignants[i].prenom)
    return res

# %%
timej = 1.34
jours  = int(timej)
timek  = (timej - jours) * 24
heures = int (timek)
minutes = int((timek - heures) * 60)

print (jours, heures, minutes)

def maketimedelta (xfloat):
    jours  = int(xfloat)
    timek  = (xfloat - jours) * 24
    heures = int (timek)
    minutes = int(round ((timek - heures) * 60))
    return datetime.timedelta (days = jours, hours = heures, minutes = minutes)

print (maketimedelta (1.2))
print (maketimedelta (0))
# Out:
# 1 8 9
# 1 day, 4:48:00
# 0:00:00

# %%
print("1-",[] == [])
print("2-", "1" == "1")
print("3-", [1, 2, 3] == [1, 2, 3])
print("4-", float("nan") == float("nan"))

coco = float("nan")
#coco = "nan"
print ("5-", coco)
print ("6-", coco == coco)
print ("7-", np.isnan (coco))
print ("8-", pd.isna(coco))
# Out:
# 1- True
# 2- True
# 3- True
# 4- False
# 5- nan
# 6- False
# 7- True
# 8- True

# %%
def add_cours_enseignant(enseignants, base, j):
    """j est le numéro de la ligne dans la base"""
    nom_enseignant = base.nom[j]
    #si un enseignant est référencé dans la ligne considérée
    timej = datetime.timedelta (hours = 0, minutes = 0)
    #if not (isinstance(nom_enseignant, (int, float))): 
    #if not (np.isnan (nom_enseignant)):
    if nom_enseignant == nom_enseignant : 
        print (nom_enseignant)
        # si l'enseignant n'est pas dans la base on l'ajoute
        if nom_enseignant not in (noms_enseignants (enseignants)):
            enseignant = Enseignant(nom_enseignant, base.prenom[j], base.statut[j])   
            Enseignants.append(enseignant)

        liste_enseignants = noms_enseignants(Enseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = enseignants[nth]
        niveau = base.niveau[j]
        if niveau == niveau: 
            enseignement = Enseignement(niveau, base.semestre[j], base.code[j], base.titre[j],base.groupes[j]) 
            cours = Cours(enseignant, enseignement)
            timej = base.duree[j]
            hetd = base.HETD[j]
            if (isinstance(hetd, (int, float))): 
                enseignement.htd = maketimedelta(hetd / 24.)
            if timej == timej: 
                cours.duree = datetime.timedelta (hours = timej.hour, minutes = timej.minute)
            else : 
                cours.duree = datetime.timedelta (hours = 0, minutes = 0)
            print (cours.duree)
            if (isinstance (base.début[j], datetime.time)):
                cours.hdebut = base.début[j]
            cours.jour = base.jour[j]
            cours.groupe = base.etudts[j]
            cours.groupes = base.groupes[j]
            cours.rqs = base.rqs[j]
            cours.plan = base.plan[j]
            if(base.TD_CM[j]==1):
                cours.type = "TD" 
            elif(base.TD_CM[j]==1.5):
                cours.type = "CM" 
            else:
                cours.type = "nil"
            salle = base.salle[j]
            if salle != salle:
                salle = "inc2"
            site = base.site[j]
            if site != site:
                site = "inc0"
            cours.salle = Salle(site, salle, salle in SallesMusic)
            print (cours.salle.site, cours.salle.code, cours.salle.music)
            enseignt = cours.enseignement
            print (enseignt.niveau, enseignt.semestre, enseignt.code)
            cours.nseances = base.nseances[j]
            #print (liste_enseignants)
            enseignant.Lcours.append(cours)
        else:
            print ("+++++++++++charge : httd :++++++++++")
            hetd = base.HETD[j]
            #if (not (isinstance(hetd, (int, float)))): 
            #    hetd = datetime.timedelta (hours = hetd)   
            if (isinstance(hetd, (int, float))): 
                hetd = maketimedelta (hetd/24.)
            charge = Charge_admin(base.titre[j],hetd)
            charge.rqs = base.rqs[j]
            print (hetd)
            enseignant.charge.append(charge)

# %%
enseignt = Enseignement("L1a", -2, "UE6", "coco" ,"jhejf")

enseignt.cours = []

print (enseignt.cours)
# Out:
# []

# %%
# => X est la base issue d'Excel
# => Enseignants est la base créée à partir de X, liste d'enseignants (de la classe Enseignant)
Enseignants = []

def readlines (base, LEnseignants):
    for j in range(base.shape[0]):
        #print (j)
        add_cours_enseignant(LEnseignants, base, 1+j)
        
# add_cours_enseignant(Enseignants, X, 150)

readlines (X, Enseignants)
# Out:
# Houles
# 3:00:00
# MDU A027 False
# L1a 1.0 UE2
# Magnana
# 1:30:00
# Tref HR8 True
# L1a 1.0 UE4
# Magnana
# 1:30:00
# Tref HR8 True
# L1a 1.0 UE4
# Dumas
# 1:30:00
# Tref J11 True
# L1a 1.0 UE4
# Dumas
# 1:30:00
# Tref J11 True
# L1a 1.0 UE4
# Fargeton
# 1:30:00
# Tref HR8 True
# L1a 1.0 UE6
# Fargeton
# 1:30:00
# Tref HR8 True
# L1a 1.0 UE6
# Pottier
# 2:00:00
# Papin A230 False
# L1a 1.0 UE6
# Y
# 1:30:00
# Papin A230 False
# L1a 1.0 UE6
# Houles
# 2:00:00
# Tref J02 True
# L1a -1.0 UE-R
# Bertrand
# 2:00:00
# Tref J11 True
# L1a -1.0 UE-R
# Bertrand
# 1:00:00
# Tref J11 True
# L1a -1.0 UE-R
# Bardot
# 2:00:00
# Tref J11 True
# L1a -1.0 UE-R
# Houles
# 3:00:00
# MDU A027 False
# L1a 2.0 UE2
# Rascle
# 2:00:00
# Papin A230 False
# L1a 2.0 UE2
# Houles
# 1:30:00
# Tref inc False
# L1a 2.0 UE6
# Houles
# 1:30:00
# Tref inc False
# L1a 2.0 UE6
# Houles
# 2:00:00
# Tref inc False
# L1a 0.0 UE-R
# Bertrand
# 2:00:00
# Tref inc False
# L1a 0.0 UE-R
# Sechehaye
# 2:00:00
# Tref inc False
# L1a 0.0 UE-R
# Desmet
# 2:00:00
# Tref J02 True
# L 1.0 UE1
# Cailliez
# 2:00:00
# Tref J02 True
# L 1.0 UE1
# Fargeton
# 1:15:00
# MDU A027 False
# L 1.0 UE2
# Fargeton
# 1:15:00
# MDU A027 False
# L 1.0 UE2
# Houles
# 1:30:00
# Tref J02 True
# L 1.0 UE3
# Houles
# 1:30:00
# Tref J02 True
# L 1.0 UE3
# Y
# 1:00:00
# inc0 inc False
# L 1.0 UE3
# Agnès
# 2:00:00
# Tref J02 True
# L 1.0 UE3
# Petiet
# 2:00:00
# Tref inc False
# L 1.0 UE3
# Houles
# 1:00:00
# MDU A027 False
# L 1.0 UE3
# Houles
# 1:00:00
# MDU A027 False
# L 1.0 UE3
# Lapalu
# 1:30:00
# Tref J02 True
# L 1.0 UE5
# Fargeton
# 1:30:00
# Tref J02 True
# L 1.0 UE5
# Cailliez
# 2:00:00
# Tref inc False
# L 2.0 UE1
# Fargeton
# 1:15:00
# MDU A027 False
# L 2.0 UE2
# Fargeton
# 1:15:00
# MDU A027 False
# L 2.0 UE2
# ATER
# 1:00:00
# MDU A027 False
# L 2.0 UE2
# Houles
# 1:30:00
# Tref inc False
# L 2.0 UE3
# Houles
# 1:30:00
# Tref inc False
# L 2.0 UE3
# Y
# 1:00:00
# inc0 inc2 False
# L 2.0 UE3
# Houles
# 2:00:00
# Tref inc False
# L 2.0 UE3
# Houles
# 2:00:00
# Tref inc False
# L 2.0 UE3
# Agnès
# 2:00:00
# Tref inc False
# L 2.0 UE3
# Petiet
# 2:00:00
# Tref inc False
# L 2.0 UE3
# Houles
# 1:00:00
# Tref inc False
# L 2.0 UE3
# Houles
# 1:00:00
# Tref inc False
# L 2.0 UE3
# Lapalu
# 1:30:00
# Tref inc False
# L 2.0 UE5
# Sechehaye
# 1:30:00
# Tref inc False
# L 2.0 UE5
# Desmet
# 1:00:00
# inc0 inc2 False
# L 2.0 nan
# Cailliez
# 1:30:00
# Tref HR8 True
# L 3.0 UE1
# Cailliez
# 1:30:00
# Tref HR8 True
# L 3.0 UE1
# Fargeton
# 2:00:00
# Tref J11 True
# L 3.0 UE1
# Forment
# 2:00:00
# Papin A201 False
# L 3.0 UE1
# Y
# 2:00:00
# Papin A201 False
# L 3.0 UE1
# Sechehaye
# 1:00:00
# Tref inc False
# L 3.0 UE1
# Houles
# 3:00:00
# MDU A027b False
# L 3.0 UE2
# Séon
# 1:00:00
# MDU A027b False
# L 3.0 UE2
# Fargeton
# 2:00:00
# MDU A027 False
# L 3.0 UE2
# Fuchs
# 2:00:00
# Tref HR8 True
# L 3.0 UE2
# Fuchs
# 2:30:00
# Tref HR8 True
# L 3.0 UE2
# Houles
# 2:00:00
# Tref J02 True
# L 3.0 UE3
# Houles
# 2:00:00
# Tref J02 True
# L 3.0 UE3
# Bertrand
# 2:00:00
# Tref HR8 True
# L 3.0 UE3
# Bertrand
# 2:00:00
# Tref HR8 True
# L 3.0 UE3
# Houles
# 1:30:00
# Tref J11 True
# L 3.0 UE3
# Tracy
# 1:30:00
# Tref inc False
# L 3.0 UE4
# Waschbüsch
# 1:30:00
# inc0 inc2 False
# L 3.0 UE6
# Desmet
# 1:30:00
# Tref inc False
# L 4.0 UE1
# Desmet
# 1:30:00
# Tref inc False
# L 4.0 UE1
# Desmet
# 1:00:00
# Tref inc False
# L 4.0 UE1
# Sechehaye
# 2:00:00
# Tref inc False
# L 4.0 UE1
# Forment
# 2:00:00
# Papin A202 False
# L 4.0 UE1
# Y
# 2:00:00
# Papin A202 False
# L 4.0 UE1
# Houles
# 3:00:00
# MDU A027b False
# L 4.0 UE2
# Fargeton
# 2:00:00
# MDU A027 False
# L 4.0 UE2
# Fuchs
# 2:00:00
# Tref inc False
# L 4.0 UE2
# Fuchs
# 2:30:00
# Tref inc False
# L 4.0 UE2
# Houles
# 2:00:00
# Tref inc False
# L 4.0 UE3
# Houles
# 2:00:00
# Tref inc False
# L 4.0 UE3
# Bertrand
# 2:00:00
# Tref inc False
# L 4.0 UE3
# Bertrand
# 2:00:00
# Tref inc False
# L 4.0 UE3
# Houles
# 1:30:00
# Tref inc False
# L 4.0 UE3
# Waschbüsch
# 1:30:00
# inc0 inc2 False
# L 4.0 UE6
# Bardot
# 2:00:00
# Tref J11 True
# L 5.0 UE1
# Waschbüsch
# 2:00:00
# Tref J11 True
# L 5.0 UE1
# Fargeton
# 2:00:00
# Tref J11 True
# L 5.0 UE1
# Pottier
# 1:30:00
# Tref HR8 True
# L 5.0 UE1
# Pottier
# 2:00:00
# Papin A201 False
# L 5.0 UE1
# Y
# 2:00:00
# Papin A201 False
# L 5.0 UE1
# Garde
# 3:00:00
# Tref J11 True
# L 5.0 UE2
# Garde
# 3:00:00
# MDU A027b False
# L 5.0 UE2
# Houles
# 2:00:00
# MDU A027 False
# L 5.0 UE2
# Fuchs
# 1:00:00
# Tref J02 True
# L 5.0 UE2
# Fuchs
# 1:00:00
# Tref J02 True
# L 5.0 UE2
# Terras
# 2:00:00
# Tref HR8 True
# L 5.0 UE3
# Viallon
# 2:00:00
# Tref J02 True
# L 5.0 UE3
# Dumas
# 1:30:00
# Tref J11 True
# L 5.0 UE4
# Desmet
# 1:30:00
# Tref J11 True
# L 5.0 UE5
# Desmet
# 1:30:00
# Tref J11 True
# L 5.0 UE5
# Cailliez
# 1:30:00
# inc0 inc2 False
# L 3.0 UE6
# Waschbüsch
# 4:00:00
# Tref inc False
# L 6.0 UE1
# Sechehaye
# 2:00:00
# Tref inc False
# L 6.0 UE1
# Pottier
# 1:30:00
# Tref inc False
# L 6.0 UE1
# Pottier
# 2:00:00
# Tref inc False
# L 6.0 UE1
# Y
# 1:00:00
# Tref inc False
# L 6.0 UE1
# Garde
# 3:00:00
# Tref inc False
# L 6.0 UE2
# Garde
# 3:00:00
# MDU A027b False
# L 6.0 UE2
# Houles
# 2:00:00
# MDU A027 False
# L 6.0 UE2
# Fuchs
# 1:00:00
# Tref inc False
# L 6.0 UE2
# Fuchs
# 1:00:00
# Tref inc False
# L 6.0 UE2
# Terras
# 2:00:00
# Tref inc False
# L 6.0 UE3
# Viallon
# 2:00:00
# Tref inc False
# L 6.0 UE3
# Clerc
# 1:30:00
# Tref inc False
# L 6.0 UE4
# Desmet
# 1:30:00
# Tref inc False
# L 6.0 UE5
# Rascle
# 1:30:00
# Tref inc False
# L 6.0 UE5
# Fargeton
# 1:00:00
# inc0 inc2 False
# L 6.0 nan
# Moussart
# 1:30:00
# Tref L21 False
# M 1.0 nan
# Pottier
# 2:00:00
# Papin A201 False
# M 1.0 nan
# Waschbüsch
# 7:30:00
# Tref inc False
# M 1.0 nan
# Sechehaye
# 4:30:00
# Tref inc False
# M 1.0 nan
# Desmet
# 2:00:00
# Tref inc False
# M 1.0 nan
# Houles
# 2:00:00
# Tref inc False
# M 1.0 nan
# Houles
# 2:00:00
# Tref inc False
# M 1.0 nan
# Aliot
# 3:00:00
# Tref inc False
# M 1.0 nan
# Aliot
# 4:00:00
# Tref inc False
# M 1.0 nan
# Aliot
# 3:00:00
# Tref inc False
# M 1.0 nan
# Carinola
# 3:00:00
# Tref inc False
# M 1.0 nan
# Carinola
# 4:00:00
# Tref inc False
# M 1.0 nan
# Borneuf
# 1:00:00
# Tref inc False
# M 1.0 nan
# Cailliez
# 3:00:00
# Tref inc False
# M 1.0 nan
# Cailliez
# 2:00:00
# Tref inc False
# M 1.0 nan
# Cailliez
# 2:00:00
# Tref inc False
# M 1.0 nan
# Sechehaye
# 2:00:00
# Tref inc False
# M 1.0 nan
# Sechehaye
# 2:00:00
# Tref inc False
# M 1.0 nan
# Sechehaye
# 3:00:00
# Tref inc False
# M 1.0 nan
# Pottier
# 3:00:00
# Tref inc False
# M 1.0 nan
# Pottier
# 2:00:00
# Tref inc False
# M 1.0 nan
# Pottier
# 3:00:00
# Tref inc False
# M 1.0 nan
# Dallès
# 1:30:00
# Tref inc False
# M 2.0 nan
# Desmet
# 3:00:00
# Tref inc False
# M 2.0 nan
# Desmet
# 2:00:00
# Tref inc False
# M 2.0 nan
# Desmet
# 2:00:00
# Tref inc False
# M 2.0 nan
# Fargeton
# 3:00:00
# Tref inc False
# M 2.0 nan
# Fargeton
# 2:00:00
# Tref inc False
# M 2.0 nan
# Fargeton
# 2:00:00
# Tref inc False
# M 2.0 nan
# Waschbüsch
# 3:00:00
# Tref inc False
# M 2.0 nan
# Waschbüsch
# 2:00:00
# Tref inc False
# M 2.0 nan
# Waschbüsch
# 2:00:00
# Tref inc False
# M 2.0 nan
# x
# 2:00:00
# Tref inc False
# M 2.0 nan
# x
# 2:00:00
# Tref inc False
# M 2.0 nan
# Dalem
# 2:00:00
# Tref inc False
# M 2.0 nan
# Dalem
# 2:00:00
# Tref inc False
# M 2.0 nan
# 2 intervenantes Cecile et Deborah)
# 3:00:00
# Tref inc False
# M 2.0 nan
# 2 intervenantes Cecile et Deborah)
# 1:00:00
# Tref inc False
# M 2.0 nan
# Cailliez
# 4:00:00
# Tref inc False
# M 1.0 nan
# Waschbüsch
# 1:30:00
# Tref inc False
# M 1.0 nan
# Pottier
# 1:30:00
# Tref inc False
# M 1.0 nan
# Fargeton
# 1:30:00
# Tref inc False
# M 1.0 nan
# Desmet
# 1:30:00
# Tref inc False
# M 1.0 nan
# Waschbüsch
# 1:00:00
# inc0 inc2 False
# AGM 3.0 nan
# Waschbüsch
# 1:00:00
# inc0 inc2 False
# AGM 3.0 nan
# Waschbüsch
# 1:00:00
# inc0 inc2 False
# AGM 3.0 nan
# Pottier
# 3:00:00
# inc0 inc2 False
# RIM 3.0 UE3-B
# Pottier
# 2:00:00
# inc0 inc2 False
# RIM 3.0 UE3-C
# Pottier
# 2:00:00
# inc0 inc2 False
# RIM 3.0 nan
# Desmet
# 1:00:00
# inc0 inc2 False
# ALL 2.0 nan
# Fargeton
# 1:00:00
# inc0 inc2 False
# ALL 2.0 nan
# Pottier
# 1:00:00
# inc0 inc2 False
# ALL 2.0 nan
# Fargeton
# 3:00:00
# inc0 inc2 False
# Comedie 1.0 nan
# Pottier
# 2:00:00
# inc0 inc2 False
# Artnum 1.0 nan
# Pottier
# +++++++++++charge : httd :++++++++++
# 1 day, 0:00:00
# Pottier
# +++++++++++charge : httd :++++++++++
# 15:00:00
# Pottier
# +++++++++++charge : httd :++++++++++
# 1 day, 0:00:00
# Desmet
# +++++++++++charge : httd :++++++++++
# 1 day, 0:00:00
# Waschbüsch
# +++++++++++charge : httd :++++++++++
# 1 day, 6:00:00
# Cailliez
# +++++++++++charge : httd :++++++++++
# 1 day, 20:00:00

# %%
dtm1 = datetime.timedelta (hours = 0, minutes = 20)
dtm2 = datetime.timedelta (hours = 10, minutes = 50)
dtm3 = datetime.timedelta (days = 0, hours = 0, minutes = 0)

#print (dir(dtm1 ))
print(str(dtm3.days*24 + int(dtm3.seconds /3600))+ "h"+ str(int(dtm3.seconds /60)%60))

def timeToStr (time):
    """time est un datetime.timedelta"""
    #print (time)
    days = time.days
    secondes = time.seconds
    res = ""
    if (secondes+days == 0):
        res = "0"
    else :
        res = str(days*24 + int(secondes /3600)%24)+ "h"+ str(int(round(secondes /60)%60))
    return res
        
print ("duree = " + timeToStr (dtm3))
print(dtm1+dtm3 )
print (dtm1*0.5)
# Out:
# 0h0
# duree = 0
# 0:20:00
# 0:10:00

# %%
def serviceR(LEnseignants, nom_enseignant):    
    liste_enseignants = noms_enseignants(LEnseignants)
    nth = liste_enseignants.index(nom_enseignant)
    enseignant = LEnseignants[nth]
    Lcours = enseignant.Lcours
    charge = enseignant.charge
    service = datetime.timedelta (hours = 0, minutes = 0)
    print("service de ", enseignant.prenom,  nom_enseignant, ":")
    for j in range(len(Lcours)):
        duree = Lcours[j].duree
        nseances = Lcours[j].nseances
        groupes = Lcours[j].groupes
        enseignement = Lcours[j].enseignement
        niveau = enseignement.niveau
        htd = enseignement.htd
        semestre = int(enseignement.semestre)
        code = enseignement.code
        #if (isinstance(code, (int, float))):
        if code != code:
            code = "Gal"            
        titre = enseignement.titre
        #if (isinstance (Lcours[j].hdebut, datetime.time)):
        hetd = htd
        #ecriture d'un cours" 
        print ("hetd" , hetd)
        
serviceR(Enseignants, "Cailliez")
# Out:
# service de  Matthieu Cailliez :
# hetd 18:00:00
# hetd 1 day, 12:00:00
# hetd 1 day, 3:00:00
# hetd 1 day, 3:00:00
# hetd 3:00:00
# hetd 4:30:00
# hetd 18:00:00
# hetd 6:00:00
# hetd 4:00:00

# %%
def service(LEnseignants, nom_enseignant):    
    liste_enseignants = noms_enseignants(LEnseignants)
    nth = liste_enseignants.index(nom_enseignant)
    enseignant = LEnseignants[nth]
    Lcours = enseignant.Lcours
    charge = enseignant.charge
    service = datetime.timedelta (hours = 0, minutes = 0)
    print("service de ", enseignant.prenom,  nom_enseignant, ":")
    for j in range(len(Lcours)):
        duree = Lcours[j].duree
        nseances = Lcours[j].nseances
        groupes = Lcours[j].groupes
        enseignement = Lcours[j].enseignement
        niveau = enseignement.niveau
        htd = enseignement.htd
        semestre = int(enseignement.semestre)
        code = enseignement.code
        if (isinstance(code, (int, float))):
            code = "Gal"            
        titre = enseignement.titre
        #if (isinstance (Lcours[j].hdebut, datetime.time)):
        hetd = htd
        #ecriture d'un cours" 
        print(niveau, "S"+str(semestre), code, titre, " : " , timeToStr(hetd), "hetd")
        service += hetd
    for j in range(len(charge)):
        hetd = charge[j].htd
        titre = charge[j].titre
        print(titre, " : " , timeToStr(hetd), "hetd")
        service += hetd
    print ("total :", timeToStr(service), "hetd")
    return service

def coefTDCM(typ):
    if(typ=="TD"):
        coef = 1
    elif(typ=="CM"):
        coef = 1.5 
    else:
        coef = 0 
    return coef
                
service(Enseignants, "Cailliez")
# Out:
# service de  Matthieu Cailliez :
# L S1 UE1 Histoire des arts - Epoque Baroque 1600-1750  :  18h0 hetd
# L S2 UE1 Histoire des arts - Epoque Classique et préromantique 1750-1830  :  36h0 hetd
# L S3 UE1 Histoire de la musique Epoque Romantique (1830-1900)  :  27h0 hetd
# L S3 UE1 Histoire de la musique Epoque Romantique (1830-1900)  :  27h0 hetd
# L S3 UE6 Initiation à la recherche  :  3h0 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  4h30 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  18h0 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  4h0 hetd
# Décharge jeune chercheur  :  44h0 hetd
# total : 187h30 hetd
# datetime.timedelta(days=7, seconds=70200)

# %%
liste_enseignants = noms_enseignants(Enseignants)
#print (liste_enseignants)
#print (liste_enseignants.index('Pottier'))
#Lcours1 = (Enseignants[2].Lcours)
#print (len(Lcours1))
#print ("durée :" , Lcours1[1].duree)

def services(LEnseignants):
    liste_enseignants = noms_enseignants(Enseignants)
    liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
    # les enseignants Musique
    for i in range (len(liste_enseignants)):
        nom_enseignant = liste_enseignants_tri[i]
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        #print (enseignant.statut)
        #service(Enseignants, liste_enseignants_tri[i])
        #if (not (isinstance(enseignant.statut, (int, float)))):
        if enseignant.statut == enseignant.statut:
            if ("Musique" in enseignant.statut):
                service(Enseignants, liste_enseignants_tri[i])
   # les autres enseignants
    for i in range (len(liste_enseignants)):
        nom_enseignant = liste_enseignants_tri[i]
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        #service(Enseignants, liste_enseignants_tri[i])
        if enseignant.statut == enseignant.statut:
            if (not "Musique" in enseignant.statut):
                service(Enseignants, liste_enseignants_tri[i])
        
services(Enseignants)
# Out:
# service de  Matthieu Cailliez :
# L S1 UE1 Histoire des arts - Epoque Baroque 1600-1750  :  18h0 hetd
# L S2 UE1 Histoire des arts - Epoque Classique et préromantique 1750-1830  :  36h0 hetd
# L S3 UE1 Histoire de la musique Epoque Romantique (1830-1900)  :  27h0 hetd
# L S3 UE1 Histoire de la musique Epoque Romantique (1830-1900)  :  27h0 hetd
# L S3 UE6 Initiation à la recherche  :  3h0 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  4h30 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  18h0 hetd
# M S1 Gal Musicologie XVIII-XIXe  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  4h0 hetd
# Décharge jeune chercheur  :  44h0 hetd
# total : 187h30 hetd
# service de  Marc Desmet :
# L S1 UE1 Histoire des arts - Epoque Baroque 1600-1750  :  18h0 hetd
# L S2 Gal Enseignant référent  :  18h0 hetd
# L S4 UE1 Histoire de la musique Epoques Moyen Age et Renaissance (avant 1600)  :  27h0 hetd
# L S4 UE1 Histoire de la musique Epoques Moyen Age et Renaissance (avant 1600)  :  27h0 hetd
# L S4 UE1 Atelier de chant Renaissance  :  18h0 hetd
# L S5 UE5 Paléographie musicale 1  :  18h0 hetd
# L S5 UE5 Iconographie musicale  :  18h0 hetd
# L S6 UE5 Paléographie musicale 2  :  18h0 hetd
# M S1 Gal Methodologie juste pour MM  :  6h0 hetd
# M S2 Gal Musicologie XVIe-XVIIe  :  4h30 hetd
# M S2 Gal Musicologie XVIe-XVIIe  :  18h0 hetd
# M S2 Gal Musicologie XVIe-XVIIe  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  1h30 hetd
# ALL S2 Gal Dialogue des Arts  :  1h30 hetd
# Mission R.I.  :  24h0 hetd
# total : 223h30 hetd
# service de  Pierre Fargeton :
# L1a S1 UE6 Methodologie  :  18h0 hetd
# L1a S1 UE6 Methodologie  :  18h0 hetd
# L S1 UE2 Musique d'ensemble  :  15h0 hetd
# L S1 UE2 Musique d'ensemble  :  15h0 hetd
# L S1 UE5 Arts et spe-jazz  :  27h0 hetd
# L S2 UE2 Musique d'ensemble  :  15h0 hetd
# L S2 UE2 Musique d'ensemble  :  15h0 hetd
# L S3 UE1 Jazz  :  36h0 hetd
# L S3 UE2 Musique d'ensemble  :  24h0 hetd
# L S4 UE2 Musique d'ensemble  :  24h0 hetd
# L S5 UE1 Jazz  :  36h0 hetd
# L S6 Gal Enseignant référent  :  12h0 hetd
# M S2 Gal Jazz  :  4h30 hetd
# M S2 Gal Jazz  :  18h0 hetd
# M S2 Gal Jazz  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  1h30 hetd
# ALL S2 Gal Dialogue des Arts  :  1h30 hetd
# Comedie S1 Gal Musicologie pour comédiens  :  9h0 hetd
# total : 295h30 hetd
# service de  Fabien Houles :
# L1a S1 UE2 Chorale  :  36h0 hetd
# L1a S-1 UE-R Lecture de la musique  :  24h0 hetd
# L1a S2 UE2 Chorale  :  36h0 hetd
# L1a S2 UE6 Methodologie  :  18h0 hetd
# L1a S2 UE6 Methodologie  :  18h0 hetd
# L1a S0 UE-R Lecture de la musique  :  24h0 hetd
# L S1 UE3 Technique analyse auditive  :  18h0 hetd
# L S1 UE3 Technique analyse auditive  :  18h0 hetd
# L S1 UE3 Formation musicale (dechif. chanté)  :  6h0 hetd
# L S1 UE3 Formation musicale (dechif. chanté)  :  6h0 hetd
# L S2 UE3 Technique analyse partition  :  18h0 hetd
# L S2 UE3 Technique analyse partition  :  18h0 hetd
# L S2 UE3 Harmonie  :  24h0 hetd
# L S2 UE3 Harmonie  :  24h0 hetd
# L S2 UE3 Formation musicale (dechif. chanté)  :  6h0 hetd
# L S2 UE3 Formation musicale (dechif. chanté)  :  6h0 hetd
# L S3 UE2 Chorale  :  0 hetd
# L S3 UE3 Harmonie  :  24h0 hetd
# L S3 UE3 Harmonie  :  24h0 hetd
# L S3 UE3 Analyse sur partitions  :  27h0 hetd
# L S4 UE2 Chorale  :  0 hetd
# L S4 UE3 Harmonie  :  24h0 hetd
# L S4 UE3 Harmonie  :  24h0 hetd
# L S4 UE3 Analyse auditive  :  27h0 hetd
# L S5 UE2 Direction de choeur  :  24h0 hetd
# L S6 UE2 Direction de choeur  :  24h0 hetd
# M S1 Gal Analyse auditive  :  9h0 hetd
# M S1 Gal Analyse auditive  :  6h0 hetd
# total : 513h0 hetd
# service de  Laurent Pottier :
# L1a S1 UE6 TICE  :  24h0 hetd
# L S5 UE1 Acoustique  :  13h30 hetd
# L S5 UE1 Acoustique  :  12h0 hetd
# L S6 UE1 Histoire des musiques électroac  :  13h30 hetd
# L S6 UE1 Histoire des musiques électroac  :  12h0 hetd
# M S1 Gal Methodologie de la recherche et du rapport de projet  :  6h0 hetd
# M S1 Gal Musiques électroacoustiques  :  4h30 hetd
# M S1 Gal Musiques électroacoustiques  :  18h0 hetd
# M S1 Gal Musiques électroacoustiques  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  1h30 hetd
# RIM S3 UE3-B Composition algorithmique  :  12h0 hetd
# RIM S3 UE3-C Dispo. audio temps réel  :  10h0 hetd
# RIM S3 Gal Projets  :  4h0 hetd
# ALL S2 Gal Dialogue des Arts  :  1h30 hetd
# Artnum S1 Gal Histoire arts nums  :  2h0 hetd
# Direction département musique  :  24h0 hetd
# Direction RIM  :  15h0 hetd
# Référent Pédagogie Numérique  :  24h0 hetd
# total : 203h30 hetd
# service de  Catherine Séon :
# L S3 UE2 Atelier de pratique vocale  :  0 hetd
# total : 0 hetd
# service de  Viviane Waschbüsch :
# L S3 UE6 PPP  :  3h0 hetd
# L S4 UE6 PPP  :  3h0 hetd
# L S5 UE1 Histoire de la musique Epoque Moderne (1900-1945)  :  36h0 hetd
# L S6 UE1 Histoire de la musique Epoque Contemporaine (après 1945)  :  72h0 hetd
# M S1 Gal Methodologie de la recherche et du rapport de projet  :  7h30 hetd
# M S2 Gal Musicologie XXe-XXIe  :  4h30 hetd
# M S2 Gal Musicologie XXe-XXIe  :  18h0 hetd
# M S2 Gal Musicologie XXe-XXIe  :  6h0 hetd
# M S1 Gal Ateliers de recherche Master Doctorat   :  1h30 hetd
# AGM S3 Gal Projet coll  :  10h0 hetd
# AGM S3 Gal Projet perso  :  9h0 hetd
# AGM S3 Gal seminaire médiation  :  12h0 hetd
# Direction AGM  :  30h0 hetd
# total : 212h30 hetd
# service de  nan 2 intervenantes Cecile et Deborah) :
# M S2 Gal Art et enfance  :  4h30 hetd
# M S2 Gal Art et enfance  :  10h0 hetd
# total : 14h30 hetd
# service de  ATER ATER :
# L S2 UE2 Atelier rythme-clave percussion  :  18h0 hetd
# total : 18h0 hetd
# service de  Viallon Agnès :
# L S1 UE3 Formation musicale  :  24h0 hetd
# L S2 UE3 Formation musicale  :  24h0 hetd
# total : 48h0 hetd
# service de  Greg Aliot :
# M S1 Gal Techniques de studio mus actuelles  :  9h0 hetd
# M S1 Gal Techniques de studio mus actuelles  :  8h0 hetd
# M S1 Gal Techniques de studio mus actuelles  :  3h0 hetd
# total : 20h0 hetd
# service de  Jean-Marc Bardot :
# L1a S-1 UE-R Repères analytiques et historiques  :  24h0 hetd
# L S5 UE1 Histoire de la musique Epoque Moderne (1900-1945)  :  36h0 hetd
# total : 60h0 hetd
# service de  Valérie Bertrand :
# L1a S-1 UE-R Formation auditive  :  24h0 hetd
# L1a S-1 UE-R Formation auditive  :  12h0 hetd
# L1a S0 UE-R Formation auditive  :  24h0 hetd
# L S3 UE3 Formation musicale  :  24h0 hetd
# L S3 UE3 Formation musicale  :  24h0 hetd
# L S4 UE3 Formation musicale  :  24h0 hetd
# L S4 UE3 Formation musicale  :  24h0 hetd
# total : 156h0 hetd
# service de  MF Borneuf :
# M S1 Gal Analyse musicale pour la médiation  :  12h0 hetd
# total : 12h0 hetd
# service de  Vincent Carinola :
# M S1 Gal Techniques de studio elec  :  6h0 hetd
# M S1 Gal Techniques de studio elec  :  4h0 hetd
# total : 10h0 hetd
# service de  Leo Clerc :
# L S6 UE4 Anglais  :  18h0 hetd
# total : 18h0 hetd
# service de  Henri Dalem :
# M S2 Gal Programmation de concerts  :  9h0 hetd
# M S2 Gal Programmation de concerts  :  6h0 hetd
# total : 15h0 hetd
# service de  Anne Dallès :
# M S2 Gal Anglais  :  15h0 hetd
# total : 15h0 hetd
# service de  Audrey Dumas :
# L1a S1 UE4 Anglais  :  18h0 hetd
# L1a S1 UE4 Anglais  :  18h0 hetd
# L S5 UE4 Anglais  :  18h0 hetd
# total : 54h0 hetd
# service de  Raphael Forment :
# L S3 UE1 Programmation informatique pour la musique  :  24h0 hetd
# L S4 UE1 Informatique musicale : lutherie numérique  :  24h0 hetd
# total : 48h0 hetd
# service de  Catherine Fuchs :
# L S3 UE2 Accompagnement  :  14h0 hetd
# L S3 UE2 Accompagnement  :  10h0 hetd
# L S4 UE2 Accompagnement  :  14h0 hetd
# L S4 UE2 Accompagnement  :  10h0 hetd
# L S5 UE2 Accompagnement  :  12h0 hetd
# L S5 UE2 Accompagnement  :  12h0 hetd
# L S6 UE2 Accompagnement  :  12h0 hetd
# L S6 UE2 Accompagnement  :  12h0 hetd
# total : 96h0 hetd
# service de  Cédric Garde :
# L S5 UE2 Pratique vocale individuelle  :  9h0 hetd
# L S5 UE2 Pratique vocale individuelle  :  15h0 hetd
# L S6 UE2 Pratique vocale individuelle  :  24h0 hetd
# L S6 UE2 Pratique vocale individuelle  :  24h0 hetd
# total : 72h0 hetd
# service de  Claire Lapalu :
# L S1 UE5 Esthétique  :  27h0 hetd
# L S2 UE5 Esthétique  :  27h0 hetd
# total : 54h0 hetd
# service de  Jessica Magnana :
# L1a S1 UE4 Français  :  18h0 hetd
# L1a S1 UE4 Français  :  18h0 hetd
# total : 36h0 hetd
# service de  Arnaud Moussart :
# M S1 Gal Anglais  :  15h0 hetd
# total : 15h0 hetd
# service de  Victor Petiet :
# L S1 UE3 Formation musicale  :  24h0 hetd
# L S2 UE3 Formation musicale  :  24h0 hetd
# total : 48h0 hetd
# service de  Lionel Rascle :
# L1a S2 UE2 Informatique musicale  :  24h0 hetd
# L S6 UE5 Musique et image  :  18h0 hetd
# total : 42h0 hetd
# service de  Hélène Sechehaye :
# L1a S0 UE-R Repères analytiques et historiques  :  24h0 hetd
# L S2 UE5 Arts et spe-ethno  :  27h0 hetd
# L S3 UE1 Atelier libre sur projets  :  18h0 hetd
# L S4 UE1 Ethnomusicologie  :  36h0 hetd
# L S6 UE1 Ethnomusicologie  :  36h0 hetd
# M S1 Gal Methodologie de la recherche et du rapport de projet  :  4h30 hetd
# M S1 Gal Ethnomusicologie  :  6h0 hetd
# M S1 Gal Ethnomusicologie  :  9h0 hetd
# M S1 Gal Ethnomusicologie  :  13h30 hetd
# total : 174h0 hetd
# service de  Bastien Terras :
# L S5 UE3 Harmonie  :  24h0 hetd
# L S6 UE3 Harmonie  :  24h0 hetd
# total : 48h0 hetd
# service de  Leland Tracy :
# L S3 UE4 Anglais  :  18h0 hetd
# total : 18h0 hetd
# service de  Agnès Viallon :
# L S5 UE3 Formation musicale  :  24h0 hetd
# L S6 UE3 Formation musicale  :  24h0 hetd
# total : 48h0 hetd
# service de  etudiant Y :
# L1a S1 UE6 TICE  :  18h0 hetd
# L S1 UE3 Technique analyse auditive  :  12h0 hetd
# L S2 UE3 Technique analyse partition  :  12h0 hetd
# L S3 UE1 Programmation informatique pour la musique  :  24h0 hetd
# L S4 UE1 Informatique musicale : lutherie numérique  :  24h0 hetd
# L S5 UE1 Acoustique  :  12h0 hetd
# L S6 UE1 Histoire des musiques électroac  :  6h0 hetd
# total : 108h0 hetd
# service de  x x :
# M S2 Gal Mediation culturelle  :  9h0 hetd
# M S2 Gal Mediation culturelle  :  6h0 hetd
# total : 15h0 hetd

# %%
a = "UJM-MCF-Musique"

"Musique" in a
# Out:
# True

# %%
def printNiveau(enseignement):
    """ pour formater le titre de l'enseignement pour les services"""
    niveau = enseignement.niveau
    semestre = int(enseignement.semestre)
    code = enseignement.code
    titre = enseignement.titre
    ligne = ""
    if code != code:
        code = "Gal"  
    if (niveau == "L1a"):
        ligne = "L1A " + " - Semestre " + str(semestre-1) + " - " + code + " " + titre
    elif (niveau == "L"):
        ligne = "Licence " + str(int((semestre+1)/2)) + " - Semestre " + str(semestre) + " - " + code + " " + titre
    elif (niveau == "M"):
        ligne = "Master " + str(int((semestre+1)/2)) + " - Semestre " + str(semestre) + " - " + code + " " + titre
    else :
        ligne = str(niveau) + " " + str(semestre) + " " + str(code) + " " + str(titre)
    return ligne
        
#enst1 =  (Enseignants[0].Lcours[1].enseignement)
#printNiveau (enst1)


def writehtml_date (filename, filout):
    now = datetime.datetime.today() 
    nowstr = now.strftime("%d/%m/%y - %I:%M")
    filout.write("<p> fichier " + filename + " - " + nowstr + "</p>\n")

# %%
print ("coco "+ str(2))
# Out:
# coco 2

# %%
def service_det_html(LEnseignants, nom_enseignant, filout):
        liste_enseignants = noms_enseignants(LEnseignants)
        nth = liste_enseignants.index(nom_enseignant)
        enseignant = LEnseignants[nth]
        Lcours = enseignant.Lcours
        charge = enseignant.charge
        service = datetime.timedelta (hours = 0, minutes = 0)
        hdebut = 0
        salle = ""
        filout.write("<h1> Service " + str(enseignant.prenom) + " " + str(nom_enseignant) + "</h1>\n")
        for j in range(len(Lcours)):
            duree = Lcours[j].duree
            nseances = Lcours[j].nseances
            groupes = Lcours[j].groupes
            print ("code0", Lcours[j].salle.code)
            if Lcours[j].salle.code == Lcours[j].salle.code: 
                print ("code1", Lcours[j].salle.code)
                print ("sirte11", Lcours[j].salle.site)
                salle = Lcours[j].salle.site + "-" + Lcours[j].salle.code
            jour = Lcours[j].jour
            duree = Lcours[j].duree
            groupe = Lcours[j].groupe
            rqs = Lcours[j].rqs
            enseignement = Lcours[j].enseignement
            htd = enseignement.htd
            #----- écriture d'un cours
            filout.write("<h2>" + printNiveau(enseignement) + "</h2>\n")
            filout.write("<p>Heures (eqtd) : " + timeToStr(htd) + " hetd</p>")
            service += htd
            if (isinstance (Lcours[j].hdebut, datetime.time)):
                hdebut = Lcours[j].hdebut
                filout.write("<p>salle "+str(salle) + " - le "+ str(jour) + " à " + str(hdebut.hour) + 
                             "h" + str(hdebut.minute) + " - " + "durée = " + timeToStr(duree))
            if groupe == groupe: 
                filout.write(" - groupes : "+ groupe )
            filout.write("</p>\n")
            if rqs == rqs: 
                filout.write("<p>rqs : "+ rqs +"</p>\n")
          
        for j in range(len(charge)):
            hetd = charge[j].htd
            titre = charge[j].titre
            rqs = charge[j].rqs
            filout.write("<h2>" + titre + "</h2>\n")
            filout.write("<p>Heures (eqtd) : "  + timeToStr(hetd) + " hetd</p>\n")
            service += hetd
            if rqs == rqs: 
                filout.write("<p>rqs : "+ rqs +"</p>\n")
        
        filout.write ("<h3>TOTAL : " + timeToStr(service) + " "+ " hetd" + "</h3>\n")


#with open("service_Pottier.txt", "w") as filout:
#    service_print(Enseignants, "Pottier", filout)

# %%
#file to write in (html version)

def services_details_html(LEnseignants, filename):    
    with open(filename, "w") as filout:
        liste_enseignants = noms_enseignants(Enseignants)
        liste_enseignants_tri = sorted(noms_enseignants(Enseignants))
        # les enseignants Musique
        filout.write ("<!DOCTYPE html>\n")
        filout.write ("<html>\n")
        filout.write ("<head>\n")
        filout.write ("<title>Services 2022-23</title>\n")
        filout.write ("<meta charset=\"utf-8\" />\n")
        filout.write ("<link href=\"styles.css\" rel=\"stylesheet\" type=\"text/css\">\n")
        filout.write ("</head>\n")
        filout.write ("<body>\n")
        writehtml_date (filename, filout)

        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #print (enseignant.statut)
            #service(Enseignants, liste_enseignants_tri[i])
            if enseignant.statut == enseignant.statut:
                if ("Musique" in enseignant.statut):
                    service_det_html(Enseignants, liste_enseignants_tri[i], filout)
       # les autres enseignants
        for i in range (len(liste_enseignants)):
            nom_enseignant = liste_enseignants_tri[i]
            nth = liste_enseignants.index(nom_enseignant)
            enseignant = LEnseignants[nth]
            #service(Enseignants, liste_enseignants_tri[i])
            if enseignant.statut == enseignant.statut:
                if (not "Musique" in enseignant.statut):
                    service_det_html(Enseignants, liste_enseignants_tri[i], filout)
        filout.write ("</body>\n")
        filout.write ("</html>")
        
                
services_details_html(Enseignants, "services_details3.html")
# Out:
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 A027
# code1 A027
# sirte11 MDU
# code0 J02
# code1 J02
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 A027
# code1 A027
# sirte11 MDU
# code0 J11
# code1 J11
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 A027
# code1 A027
# sirte11 MDU
# code0 J11
# code1 J11
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 A027
# code1 A027
# sirte11 MDU
# code0 J02
# code1 J02
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 A027
# code1 A027
# sirte11 MDU
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A027b
# code1 A027b
# sirte11 MDU
# code0 J02
# code1 J02
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 A027b
# code1 A027b
# sirte11 MDU
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 A027
# code1 A027
# sirte11 MDU
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A230
# code1 A230
# sirte11 Papin
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 A201
# code1 A201
# sirte11 Papin
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A201
# code1 A201
# sirte11 Papin
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 A027b
# code1 A027b
# sirte11 MDU
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 J11
# code1 J11
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A027
# code1 A027
# sirte11 MDU
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 A201
# code1 A201
# sirte11 Papin
# code0 A202
# code1 A202
# sirte11 Papin
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J11
# code1 J11
# sirte11 Tref
# code0 A027b
# code1 A027b
# sirte11 MDU
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A027b
# code1 A027b
# sirte11 MDU
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 L21
# code1 L21
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A230
# code1 A230
# sirte11 Papin
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 HR8
# code1 HR8
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 J02
# code1 J02
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 A230
# code1 A230
# sirte11 Papin
# code0 inc
# code1 inc
# sirte11 inc0
# code0 inc2
# code1 inc2
# sirte11 inc0
# code0 A201
# code1 A201
# sirte11 Papin
# code0 A202
# code1 A202
# sirte11 Papin
# code0 A201
# code1 A201
# sirte11 Papin
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref
# code0 inc
# code1 inc
# sirte11 Tref

# %% [markdown]
# ## now = datetime.datetime.today()
# nowstr = now.strftime("%d/%m/%y-%I:%M")
# print ("date :" + str(nowstr))
# print ("date :" + str(now))

# %%
## à faire : durée à mettre en format time

# %% [markdown]
# ## 2-Planning (graphique)

# %%
class Annee:
    def __init__ (self, annee, semestre1, semestre2, admin):
        self.annee = annee
        self.semestre1 = semestre1
        self.semestre2 = semestre2
        self.admin = admin
    
class Semestre:
    def __init__ (self, semestre, Lcours):
        self.semestre = semestre     
        self.Lcours = Lcours       
        
class Table:
    def __init__ (self):
        self.trs = []
        self.infos = ""
        
class Tr:
    def __init__ (self):
        self.tds = []
        self.salle = Salle()
        
class Td:
    def __init__ (self, cours):
        self.cours = cours

# %%
       
def findSalle(code, Lsalles):
    res = 0
    for j in range (len(Lsalles)):
        if (code == Lsalles[j].code):
            res = 1
            break
    return res
    
def Lsalles(base):
    Lres = []
    salle = "nil"
    for j in range(base.shape[0]):
        site = base.site[1+j]
        code = base.salle[1+j]
        if not (isinstance(code, (int, float))):
            print(site, code, code in SallesMusic)
            salle = Salle(site, code, code in SallesMusic)
            #print (findSalle(code , Lres))
            if not (findSalle(code , Lres))  :
                #print("kjkjkj")
                Lres.append (salle)
    return Lres

SallesDeCours = Lsalles (X) 

SallesDeCours.sort(key=operator.attrgetter('code'))
SallesDeCours.sort(key=operator.attrgetter('site'), reverse=True)
SallesDeCours.sort(key=operator.attrgetter('music'), reverse=True)

for n in range(len(SallesDeCours)):
    print (SallesDeCours[n].site + "-" +SallesDeCours[n].code) 

#print (findSalle('A230' , SallesDeCours))
#print(SallesDeCours)
# Out:
# MDU A027 False
# Tref HR8 True
# Tref HR8 True
# Tref J11 True
# Tref J11 True
# Tref HR8 True
# Tref HR8 True
# Papin A230 False
# Papin A230 False
# Tref J02 True
# Tref J11 True
# Tref J11 True
# Tref J11 True
# MDU A027 False
# Papin A230 False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref J02 True
# Tref J02 True
# MDU A027 False
# MDU A027 False
# Tref J02 True
# Tref J02 True
# nan inc False
# Tref J02 True
# Tref inc False
# MDU A027 False
# MDU A027 False
# Tref J02 True
# Tref J02 True
# Tref inc False
# MDU A027 False
# MDU A027 False
# MDU A027 False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref HR8 True
# Tref HR8 True
# Tref J11 True
# Papin A201 False
# Papin A201 False
# Tref inc False
# MDU A027b False
# MDU A027b False
# MDU A027 False
# Tref HR8 True
# Tref HR8 True
# Tref J02 True
# Tref J02 True
# Tref HR8 True
# Tref HR8 True
# Tref J11 True
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Papin A202 False
# Papin A202 False
# MDU A027b False
# MDU A027 False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref J11 True
# Tref J11 True
# Tref J11 True
# Tref HR8 True
# Papin A201 False
# Papin A201 False
# Tref J11 True
# MDU A027b False
# MDU A027 False
# Tref J02 True
# Tref J02 True
# Tref HR8 True
# Tref J02 True
# Tref J11 True
# Tref J11 True
# Tref J11 True
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# MDU A027b False
# MDU A027 False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref L21 False
# Papin A201 False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref inc False
# Tref-HR8
# Tref-J02
# Tref-J11
# Tref-L21
# Tref-inc
# Papin-A201
# Papin-A202
# Papin-A230
# MDU-A027
# MDU-A027b

# %%
# faire un tableau html graphique
# on trie d'abord les enseignements pour les mettre chacun dans un semestre
# on trie ensuite les enseignements du semestre pour les mettre chacun dans un jour de la semaine
# on trie ensuite les enseigneemnts d'un jour pour les mettre chacun dans une salle
# on prend enfin une salle et un jour et on produit le <tr> correspondant en fonction de l'heure et de la durée

# %%
Enseignants[1].Lcours[1].hdebut
# Out:
# datetime.time(15, 0)

# %%
-1 % 2
# Out:
# 1

# %%
Lcours_Simpair = []
Lcours_Spair = []

for i in range (len(Enseignants)):
    for j in range (len(Enseignants[i].Lcours)):
        # 
        if (Enseignants[i].Lcours[j].enseignement.semestre % 2 == 1):
            if (isinstance (Enseignants[i].Lcours[j].hdebut, datetime.time)):
                Lcours_Simpair.append(Enseignants[i].Lcours[j])
                #print (Enseignants[i].Lcours[j].hdebut)
                x = len(Lcours_Simpair)
                #print ("b", Lcours_Simpair[x-1].Lcours[j].hdebut)
                #print ("b", Lcours_Simpair[x-1].hdebut)
       # elif (Enseignants[i].Lcours[j].enseignement.semestre % 2 == 0):
        #    Lcours_Spair.append(Enseignants[i].Lcours[j])
            
print ("---------------")     

for i in range (len(Enseignants)):
    for j in range (len(Enseignants[i].Lcours)):
        if (Enseignants[i].Lcours[j].enseignement.semestre % 2 == 0):
            if (isinstance (Enseignants[i].Lcours[j].hdebut, datetime.time)):
                Lcours_Spair.append(Enseignants[i].Lcours[j])
                #print (Enseignants[i].cours[j].hdebut)
                x = len(Lcours_Spair)
                #print ("b", Lcours_Simpair[x-1].cours[j].hdebut)
                #print ("b", Lcours_Simpair[x-1].hdebut)
       # elif (Enseignants[i].Lcours[j].enseignement.semestre % 2 == 0):
        #    Lcours_Spair.append(Enseignants[i].cours[j])
            
print ("---------------")     
            
for i in range (len(Lcours_Simpair)):
    print ("S",(Lcours_Simpair[i].enseignement.semestre) , "-" , 
           Lcours_Simpair[i].enseignant.nom , " ", (Lcours_Simpair[i].hdebut))
    
print ("---------------")    
            
for i in range (len(Lcours_Spair)):
    print ("S",(Lcours_Spair[i].enseignement.semestre) , "-" , 
           Lcours_Spair[i].enseignant.nom , " ", (Lcours_Spair[i].hdebut))
# Out:
# ---------------
# ---------------
# S 1.0 - Houles   14:00:00
# S -1.0 - Houles   08:45:00
# S 1.0 - Houles   14:30:00
# S 1.0 - Houles   16:00:00
# S 1.0 - Houles   08:00:00
# S 1.0 - Houles   09:00:00
# S 3.0 - Houles   14:00:00
# S 3.0 - Houles   10:30:00
# S 3.0 - Houles   13:30:00
# S 3.0 - Houles   11:00:00
# S 5.0 - Houles   17:00:00
# S 1.0 - Magnana   13:30:00
# S 1.0 - Magnana   15:00:00
# S 1.0 - Dumas   13:30:00
# S 1.0 - Dumas   15:00:00
# S 5.0 - Dumas   16:30:00
# S 1.0 - Fargeton   09:00:00
# S 1.0 - Fargeton   10:30:00
# S 1.0 - Fargeton   10:30:00
# S 1.0 - Fargeton   11:45:00
# S 1.0 - Fargeton   15:45:00
# S 3.0 - Fargeton   08:45:00
# S 3.0 - Fargeton   08:00:00
# S 5.0 - Fargeton   13:30:00
# S 1.0 - Pottier   08:30:00
# S 5.0 - Pottier   10:30:00
# S 5.0 - Pottier   08:30:00
# S 1.0 - Pottier   17:15:00
# S 1.0 - Y   10:30:00
# S 3.0 - Y   10:30:00
# S 5.0 - Y   10:30:00
# S -1.0 - Bertrand   09:00:00
# S -1.0 - Bertrand   08:00:00
# S 3.0 - Bertrand   13:30:00
# S 3.0 - Bertrand   15:45:00
# S -1.0 - Bardot   14:00:00
# S 5.0 - Bardot   11:00:00
# S 1.0 - Desmet   13:30:00
# S 5.0 - Desmet   10:45:00
# S 1.0 - Cailliez   13:30:00
# S 3.0 - Cailliez   10:30:00
# S 3.0 - Cailliez   15:00:00
# S 1.0 - Agnès   16:30:00
# S 1.0 - Petiet   16:30:00
# S 1.0 - Lapalu   11:30:00
# S 3.0 - Forment   08:30:00
# S 3.0 - Fuchs   10:00:00
# S 3.0 - Fuchs   10:00:00
# S 5.0 - Fuchs   10:30:00
# S 5.0 - Fuchs   11:30:00
# S 3.0 - Tracy   14:00:00
# S 5.0 - Waschbüsch   08:30:00
# S 1.0 - Waschbüsch   15:45:00
# S 5.0 - Garde   08:00:00
# S 5.0 - Garde   08:00:00
# S 5.0 - Terras   13:30:00
# S 5.0 - Viallon   14:30:00
# ---------------
# S 2.0 - Houles   14:00:00
# S 4.0 - Houles   14:00:00
# S 6.0 - Houles   17:00:00
# S 2.0 - Fargeton   10:30:00
# S 2.0 - Fargeton   11:45:00
# S 4.0 - Fargeton   08:00:00
# S 4.0 - Y   11:00:00
# S 4.0 - Sechehaye   09:15:00
# S 4.0 - Desmet   15:15:00
# S 4.0 - Desmet   11:30:00
# S 4.0 - Desmet   11:30:00
# S 4.0 - Forment   09:00:00

# %%
#len(cours_Simpair)
Lcours_Spair[1].hdebut
# Out:
# datetime.time(14, 0)

# %%
coco = Lcours_Simpair[0]
coco.plan in ["L", "L1a"]
# Out:
# True

# %%
# remplissage des journées avec les différents cours qui composent la licence
SemestresImpairs= []

Lcours_lundi_Simpair = []
Lcours_mardi_Simpair = []
Lcours_mercredi_Simpair = []
Lcours_jeudi_Simpair = []
Lcours_vendredi_Simpair = []

for j in range (len(Lcours_Simpair )):
    if (Lcours_Simpair[j].jour == "lundi" and Lcours_Simpair[j].plan in ["L", "L1a"]):
        Lcours_lundi_Simpair.append(Lcours_Simpair[j])
    elif (Lcours_Simpair[j].jour == "mardi" and Lcours_Simpair[j].plan  in ["L", "L1a"]):
        Lcours_mardi_Simpair.append(Lcours_Simpair[j])
    elif (Lcours_Simpair[j].jour == "mercredi" and Lcours_Simpair[j].plan  in ["L", "L1a"]):
        Lcours_mercredi_Simpair.append(Lcours_Simpair[j])
    elif (Lcours_Simpair[j].jour == "jeudi" and Lcours_Simpair[j].plan  in ["L", "L1a"]):
        Lcours_jeudi_Simpair.append(Lcours_Simpair[j])
    elif (Lcours_Simpair[j].jour == "vendredi" and Lcours_Simpair[j].plan  in ["L", "L1a"]):
        Lcours_vendredi_Simpair.append(Lcours_Simpair[j])
        
SemestresImpairs.append(Lcours_lundi_Simpair)  
SemestresImpairs.append(Lcours_mardi_Simpair)  
SemestresImpairs.append(Lcours_mercredi_Simpair)  
SemestresImpairs.append(Lcours_jeudi_Simpair)  
SemestresImpairs.append(Lcours_vendredi_Simpair)     

for jourcours in SemestresImpairs:
    jourcours.sort(key=operator.attrgetter('hdebut'))
    jourcours.sort(key=operator.attrgetter('salle.code'))
    jourcours.sort(key=operator.attrgetter('salle.site'),  reverse=True)
    jourcours.sort(key=operator.attrgetter('salle.music'), reverse=True)

    
print ("Lcours_mercredi_Simpair")
for i in range (len(Lcours_mercredi_Simpair)):
    Lcours = Lcours_mercredi_Simpair[i]
    print (str(Lcours.salle.code) + "-" + Lcours.enseignant.nom+ "-" + Lcours.enseignement.titre)
    print (str(Lcours.enseignement.niveau)+ "-" + str(int (Lcours.enseignement.semestre)))
#print (Lcours_lundi_Simpair[1].hdebut)
#semestre1 = Semestre(coursS1)

SemestrImpairs = Semestre("Semestres impairs", SemestresImpairs)
# Out:
# Lcours_mercredi_Simpair
# J02-Houles-Harmonie
# L-3
# J11-Bertrand-Formation auditive
# L1a--1
# J11-Bertrand-Formation auditive
# L1a--1
# A027-Fargeton-Musique d'ensemble
# L-3
# A027-Fargeton-Musique d'ensemble
# L-1
# A027-Fargeton-Musique d'ensemble
# L-1
# A027-Houles-Chorale
# L1a-1
# A027-Houles-Direction de choeur
# L-5
# A027b-Houles-Chorale
# L-3

# %%
for jourcours in SemestresImpairs:
    for coursx in jourcours:
        print (coursx.salle.code)
    #print (jourcours)
# Out:
# HR8
# HR8
# HR8
# J02
# J02
# J02
# J02
# J11
# J11
# J11
# inc
# inc
# A230
# A230
# HR8
# HR8
# HR8
# HR8
# J02
# J02
# J11
# J11
# A201
# A201
# J02
# J11
# J11
# A027
# A027
# A027
# A027
# A027
# A027b
# HR8
# HR8
# J02
# J02
# J02
# J02
# J11
# J11
# J11
# A201
# A201
# HR8
# HR8
# J02
# J11
# J11
# J11
# A027
# A027
# A027b

# %%
# remplissage des journées avec les différents cours qui la composent
SemestresPairs= []

Lcours_lundi_Spair = []
Lcours_mardi_Spair = []
Lcours_mercredi_Spair = []
Lcours_jeudi_Spair = []
Lcours_vendredi_Spair = []

for j in range (len(Lcours_Spair )):
    if (Lcours_Spair[j].jour == "lundi" and Lcours_Spair[j].plan in ["L", "L1a"]):
        Lcours_lundi_Spair.append(Lcours_Spair[j])
    elif (Lcours_Spair[j].jour == "mardi" and Lcours_Spair[j].plan in ["L", "L1a"]):
        Lcours_mardi_Spair.append(Lcours_Spair[j])
    elif (Lcours_Spair[j].jour == "mercredi" and Lcours_Spair[j].plan in ["L", "L1a"]):
        Lcours_mercredi_Spair.append(Lcours_Spair[j])
    elif (Lcours_Spair[j].jour == "jeudi" and Lcours_Spair[j].plan in ["L", "L1a"]):
        Lcours_jeudi_Spair.append(Lcours_Spair[j])
    elif (Lcours_Spair[j].jour == "vendredi" and Lcours_Spair[j].plan in ["L", "L1a"]):
        Lcours_vendredi_Spair.append(Lcours_Spair[j])
        
SemestresPairs.append(Lcours_lundi_Spair)  
SemestresPairs.append(Lcours_mardi_Spair)  
SemestresPairs.append(Lcours_mercredi_Spair)  
SemestresPairs.append(Lcours_jeudi_Spair)  
SemestresPairs.append(Lcours_vendredi_Spair)     

for jourcours in SemestresPairs:
    jourcours.sort(key=operator.attrgetter('hdebut'))
    jourcours.sort(key=operator.attrgetter('salle.code'))
    jourcours.sort(key=operator.attrgetter('salle.site'),  reverse=True)
    jourcours.sort(key=operator.attrgetter('salle.music'), reverse=True)

    
print ("Lcours_jeudi_Spair")
for i in range (len(Lcours_jeudi_Spair)):
   print (str(Lcours_jeudi_Spair[i].salle.code) + "-" + Lcours_jeudi_Spair[i].enseignant.nom+ "-" + Lcours_jeudi_Spair[i].enseignement.titre)
#print (cours_lundi_Spair[1].hdebut)

SemestrPairs = Semestre("Semestres pairs", SemestresPairs)
# Out:
# Lcours_jeudi_Spair

# %%
coco = 5
coco in [1, 2, 5]
# Out:
# True

# %%
def SallesJour(LcoursDuJour):
    codes = []
    salles = []
    for i in range (len (LcoursDuJour)):
        salle = LcoursDuJour[i].salle
        code = salle.code
        if (code == code) :
            if (not code in codes):
                codes.append(code)
                salles.append(salle)
    return salles
            
len(SallesJour(SemestresImpairs[0]))

def SallesJour_annee(LcoursDuJour, semest):
    codes = []
    salles = []
    for i in range (len (LcoursDuJour)):
        salle = LcoursDuJour[i].salle
        code = salle.code
        sem = LcoursDuJour[i].enseignement.semestre
        if (code == code) and sem in semest:
                if (not code in codes):
                    codes.append(code)
                    salles.append(salle)
    return salles
            
len(SallesJour(SemestresImpairs[0]))
len(SallesJour_annee(SemestresImpairs[0], [1, 5]))
# Out:
# 5

# %%
print ("i = " , (len(SemestresImpairs)))
for i in range (len(SemestresImpairs)):
    print ("j = " , (len(SemestresImpairs[i])))
    for j in range (len(SemestresImpairs[i])):
        print (SemestresImpairs[i][j].enseignement.titre)
        print (SemestresImpairs[i][j].enseignement.semestre)
        print (SemestresImpairs[i][j].enseignement.niveau)
# Out:
# i =  5
# j =  14
# Histoire de la musique Epoque Romantique (1830-1900)
# 3.0
# L
# Français
# 1.0
# L1a
# Français
# 1.0
# L1a
# Accompagnement
# 5.0
# L
# Accompagnement
# 5.0
# L
# Formation musicale
# 5.0
# L
# Formation musicale
# 1.0
# L
# Anglais
# 1.0
# L1a
# Anglais
# 1.0
# L1a
# Anglais
# 5.0
# L
# Anglais
# 3.0
# L
# Formation musicale
# 1.0
# L
# TICE
# 1.0
# L1a
# TICE
# 1.0
# L1a
# j =  10
# Methodologie
# 1.0
# L1a
# Methodologie
# 1.0
# L1a
# Harmonie
# 5.0
# L
# Formation musicale
# 3.0
# L
# Histoire des arts - Epoque Baroque 1600-1750
# 1.0
# L
# Arts et spe-jazz
# 1.0
# L
# Histoire de la musique Epoque Moderne (1900-1945)
# 5.0
# L
# Paléographie musicale 1
# 5.0
# L
# Programmation informatique pour la musique
# 3.0
# L
# Programmation informatique pour la musique
# 3.0
# L
# j =  9
# Harmonie
# 3.0
# L
# Formation auditive
# -1.0
# L1a
# Formation auditive
# -1.0
# L1a
# Musique d'ensemble
# 3.0
# L
# Musique d'ensemble
# 1.0
# L
# Musique d'ensemble
# 1.0
# L
# Chorale
# 1.0
# L1a
# Direction de choeur
# 5.0
# L
# Chorale
# 3.0
# L
# j =  11
# Acoustique
# 5.0
# L
# Histoire de la musique Epoque Romantique (1830-1900)
# 3.0
# L
# Lecture de la musique
# -1.0
# L1a
# Esthétique
# 1.0
# L
# Technique analyse auditive
# 1.0
# L
# Technique analyse auditive
# 1.0
# L
# Jazz
# 3.0
# L
# Analyse sur partitions
# 3.0
# L
# Jazz
# 5.0
# L
# Acoustique
# 5.0
# L
# Acoustique
# 5.0
# L
# j =  9
# Accompagnement
# 3.0
# L
# Formation musicale
# 3.0
# L
# Harmonie
# 3.0
# L
# Pratique vocale individuelle
# 5.0
# L
# Histoire de la musique Epoque Moderne (1900-1945)
# 5.0
# L
# Repères analytiques et historiques
# -1.0
# L1a
# Formation musicale (dechif. chanté)
# 1.0
# L
# Formation musicale (dechif. chanté)
# 1.0
# L
# Pratique vocale individuelle
# 5.0
# L

# %%
def printNiveauR(enseignement):
    niveau = enseignement.niveau
    semestre = int(enseignement.semestre)
    if (niveau == "L1a"):
        ligne = niveau + str(int((semestre+1)/2))
    elif (niveau == "L"):
        ligne = niveau + str(int((semestre+1)/2))
    elif (niveau == "M"):
        ligne = "M" + str(int((semestre+1)/2)) 
    return ligne
        
print (printNiveauR(SemestresImpairs[0][1].enseignement))
print (printNiveauR(SemestresImpairs[0][0].enseignement))
print (printNiveauR(SemestresImpairs[0][7].enseignement))
# Out:
# L1a1
# L2
# L1a1

# %%
# créer la cellule d'un cours
print(SemestresImpairs[0][1].jour)
# Out:
# lundi

# %%
print(SemestresImpairs[1])
# Out:
# [<__main__.Cours object at 0x7f79c06bcc10>, <__main__.Cours object at 0x7f79c06bc370>, <__main__.Cours object at 0x7f79e04a9640>, <__main__.Cours object at 0x7f79e04b1d30>, <__main__.Cours object at 0x7f79e0497190>, <__main__.Cours object at 0x7f79e04a7f70>, <__main__.Cours object at 0x7f79c06e39d0>, <__main__.Cours object at 0x7f79e04b19d0>, <__main__.Cours object at 0x7f79e04a4880>, <__main__.Cours object at 0x7f79e04b0070>]

# %%
# il suffit de trier les cours d'une journée par salle puis par horaires
# puis tester les conflits horaires dans une salle !!!!!!!!!!!!
# créer les cellules vides qui précédent

def printhtmljour(LcoursDuJour, flag, filout):
    """flag = numéro du semestre (L0 => -2 et -1)"""
    jour = LcoursDuJour[1].jour
    premierjour = True
    sallesJour = SallesJour(LcoursDuJour)
    nsalles = len(sallesJour)
    createhtmlTDjour(jour, nsalles, flag, filout)
    for salle in sallesJour:
        hdebut = datetime.timedelta (hours = 8, minutes = 0)
        hfin = datetime.timedelta (hours = 19, minutes = 0)
        if not premierjour :
            createhtmlTR(1, filout)
            premierjour = False
        site = salle.site
        code = salle.code
        createhtmlTDsalle (site, code, filout)
        for i in range (len (LcoursDuJour)):
        #"voir quoi faire avec les salles nan"
            if (LcoursDuJour[i].salle.code == code):
                hdebut = createhtmlTD (hdebut, LcoursDuJour[i], filout)                
        dureeLibre = hfin - hdebut
        ncellvides = int(dureeLibre.seconds / (15*60))
        if not ncellvides == 0:
            filout.write("<td colspan=" + str( ncellvides) + " " +  "class=cellvide>&nbsp;</td>")
        createhtmlTR(0, filout)  

def printhtmljour_annee(LcoursDuJour, flag, semest, filout):
    createhtmlTR(1, filout)
    jour = LcoursDuJour[1].jour
    premierjour = True
    sallesJour = SallesJour_annee(LcoursDuJour, semest)
    nsalles = len(sallesJour)
    print ("nsalles" , semest )
    createhtmlTDjour(jour, nsalles, flag, filout)
    for salle in sallesJour:
        hdebut = datetime.timedelta (hours = 8, minutes = 0)
        hfin = datetime.timedelta (hours = 19, minutes = 0)
        if not premierjour :
            createhtmlTR(1, filout)
            premierjour = False
        site = salle.site
        code = salle.code
        createhtmlTDsalle (site, code, filout)
        for i in range (len (LcoursDuJour)):
        #"voir quoi faire avec les salles nan"
            if (LcoursDuJour[i].enseignement.semestre in semest and LcoursDuJour[i].salle.code == code):
                hdebut = createhtmlTD (hdebut, LcoursDuJour[i], filout)                
        dureeLibre = hfin - hdebut
        ncellvides = int(dureeLibre.seconds / (15*60))
        if not ncellvides == 0:
            filout.write("<td colspan=" + str( ncellvides) + " " +  "class=cellvide>&nbsp;</td>")
        createhtmlTR(0, filout)  

def createhtmlTR(flag, filout):
    if flag  == 1: filout.write("<tr>\n")
    else: filout.write("</tr>\n")
    
def createhtmlTDjour(jour, nsalles, flag, filout):
    if flag == 1:
        filout.write("<td class=celljour rowspan="+str(nsalles)+">"+ jour + "</td>\n")
    else:
        filout.write("<td class=celljour2 rowspan="+str(nsalles)+">"+ jour + "</td>\n")
    
def createhtmlTDsalle(site, code, filout):
    filout.write("<td class=cellsalle>" + site +"</td>\n")
    filout.write("<td class=cellsalle>" + code +"</td>\n")
    
        
def createhtmlTD(heureref, cours, filout):
    heure = cours.hdebut
    duree = cours.duree
    hdebut = datetime.timedelta(hours = heure.hour, minutes = heure.minute)  
    dureeLibre = hdebut - heureref
    ncellvides = int(dureeLibre.seconds / (15*60))
    ncellpleines = int(duree.seconds / (15*60))
    rqs = cours.rqs
    grp = cours.groupe
    if rqs!=rqs: rqs = ""
    else: rqs = "-"+rqs
    if grp!=grp: grp = ""
    else: grp = "-"+grp
    rqs =  rqs+grp   
    #print ("coursdebut = " , cours.hdebut, " -  duree : " , dureeLibre,)
    if not ncellvides == 0:
        filout.write("<td colspan=" + str( ncellvides) + " " +  "class=cellvide>&nbsp;</td>")
    filout.write("<td colspan=" + str(ncellpleines) + " "  "class=cell"+printNiveauR(cours.enseignement)+">"+
                 printNiveauR(cours.enseignement)+"-"+cours.enseignement.titre+
                 "-"+cours.enseignant.prenom[0]+"."+cours.enseignant.nom+rqs+"</td>\n")
    return hdebut + duree

# %%
def printHtmlHeures(filout):
    "pour afficher le bandeau horaire"
    heure = datetime.timedelta (hours = 8)  
    heurefin = datetime.timedelta (hours = 19)  
    filout.write("<tr>\n")
    filout.write("<td colspan=3 class=cellhor>&nbsp;</td>\n")
    i = 0
    "modifications horaires"
    while heure < heurefin :
        if (i==0) :
            filout.write("<td class=cellhorb>" + str(int(heure.seconds/3600)) + "h</td>\n")
            heure += datetime.timedelta (minutes = 15)
            i = (i+1)%4
        else :
            filout.write("<td class=cellhor>" + str(int(heure.seconds/3600)) + "h" + str(int((heure.seconds/60)%60)) + "</td>\n")
            heure += datetime.timedelta (minutes = 15)
            i = (i+1)%4
        
    filout.write("</tr>\n")
        
#printHtmlHeures("lll")

# %%
def planning_html_Sems(LEnseignants, Semestres, filename):    
    with open(filename, "w") as filout:
        filout.write ("<!DOCTYPE html>\n")
        filout.write ("<html>\n")
        filout.write ("<head>\n")
        filout.write ("<title>"+filename+"</title>\n")
        filout.write ("<meta charset=\"utf-8\" />\n")
        filout.write ("<link href=\"styleP.css\" rel=\"stylesheet\" type=\"text/css\">\n")
        filout.write ("</head>\n")
        filout.write ("<body>\n")
        filout.write ("<table border=0 cellpadding=0 cellspacing=0>\n")
        filout.write ("<tr>\n<td class=titre colspan=8>"+Semestres.semestre+"</td>\n")
        filout.write ("<td class=colorL0>L0</td>\n")
        filout.write ("<td class=colorL1a>L1a</td>\n")
        filout.write ("<td class=colorL1>L1b</td>\n")
        filout.write ("<td class=colorL2>L2</td>\n")
        filout.write ("<td class=colorL3>L3</td>\n")
        filout.write ("<td class=bluecell colspan=34>&nbsp;</td>\n")
        filout.write ("</tr>\n")
        
        flag = 1

        for jour in Semestres.Lcours:
            printHtmlHeures(filout)
            printhtmljour  (jour, flag, filout)
            flag = (flag + 1) %2 
        filout.write ("</table>\n")
        writehtml_date (filename, filout)
        filout.write ("</body>\n")
        filout.write ("</html>\n")
        
planning_html_Sems(Enseignants, SemestrImpairs, "planningS1_2022-23auto.html")
#planning_html_Sems(Enseignants, SemestrPairs, "planningS2_2022-23auto.html")

# %%
# ajouter le Master Musicologie Recherche
def planning_html_Sem(LEnseignants, Semestres, semest, filename):    
    with open(filename, "w") as filout:
        filout.write ("<!DOCTYPE html>\n")
        filout.write ("<html>\n")
        filout.write ("<head>\n")
        filout.write ("<title>"+filename+"</title>\n")
        filout.write ("<meta charset=\"utf-8\" />\n")
        filout.write ("<link href=\"styleP.css\" rel=\"stylesheet\" type=\"text/css\">\n")
        filout.write ("</head>\n")
        filout.write ("<body>\n")
        filout.write ("<table border=0 cellpadding=0 cellspacing=0>\n")
        filout.write ("<tr>\n<td class=titre colspan=8>"+Semestres.semestre+"</td>\n")
        filout.write ("<td class=colorL0>L0</td>\n")
        filout.write ("<td class=colorL1a>L1a</td>\n")
        filout.write ("<td class=colorL1>L1b</td>\n")
        filout.write ("<td class=colorL2>L2</td>\n")
        filout.write ("<td class=colorL3>L3</td>\n")
        filout.write ("<td class=bluecell colspan=36>&nbsp;</td>\n")
        filout.write ("</tr>\n")
        flag = 1

        for jour in Semestres.Lcours:
            printHtmlHeures(filout)
            printhtmljour_annee  (jour, flag, semest, filout)
            flag = (flag + 1) %2 
        filout.write ("</table>\n")
        writehtml_date (filename, filout)
        filout.write ("</body>\n")
        filout.write ("</html>\n")
        
planning_html_Sem(Enseignants, SemestrImpairs, [-1, 1], "planningS1L0_2022-23auto.html")
planning_html_Sem(Enseignants, SemestrImpairs, [1], "planningS1L1_2022-23auto.html")
planning_html_Sem(Enseignants, SemestrImpairs, [3], "planningS1L2_2022-23auto.html")
planning_html_Sem(Enseignants, SemestrImpairs, [5], "planningS1L3_2022-23auto.html")
#planning_html_Sem(Enseignants, SemestrPairs, 0, "planningS2L0_2022-23auto.html")
#planning_html_Sem(Enseignants, SemestrPairs, 2, "planningS2L1_2022-23auto.html")
#planning_html_Sem(Enseignants, SemestrPairs, 4, "planningS2L2_2022-23auto.html")
#planning_html_Sem(Enseignants, SemestrPairs, 6, "planningS2L3_2022-23auto.html")
# Out:
# nsalles [-1, 1]
# nsalles [-1, 1]
# nsalles [-1, 1]
# nsalles [-1, 1]
# nsalles [-1, 1]
# nsalles [1]
# nsalles [1]
# nsalles [1]
# nsalles [1]
# nsalles [1]
# nsalles [3]
# nsalles [3]
# nsalles [3]
# nsalles [3]
# nsalles [3]
# nsalles [5]
# nsalles [5]
# nsalles [5]
# nsalles [5]
# nsalles [5]

# %%
flag = 1

for x in range (4):
    print(flag)
    flag = (flag + 1 )%2
# Out:
# 1
# 0
# 1
# 0
